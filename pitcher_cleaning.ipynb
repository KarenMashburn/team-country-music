# %%
# Import dependencies
import pandas as pd

# %%
# Read the data
bauer_df = pd.read_csv('bauer.csv')
bieber_df = pd.read_csv('bieber.csv')
buehler_df = pd.read_csv('buehler.csv')
cole_df = pd.read_csv('cole.csv')
degrom_df = pd.read_csv('degrom.csv')
kershaw_df = pd.read_csv('kershaw.csv')
lamet_df = pd.read_csv('lamet.csv')
nola_df = pd.read_csv('nola.csv')
scherzer_df = pd.read_csv('scherzer.csv')

# %%
pitcher_df = pd.concat([bauer_df, bieber_df, buehler_df, cole_df, degrom_df, kershaw_df, lamet_df, nola_df, scherzer_df])

# %%
pitcher_df
# Out:
#      Unnamed: 0 pitch_type  release_speed  release_pos_x  release_pos_z  \
# 0         18993         KC           80.8          -1.25           5.89
# 1         18994         KC           79.6          -1.44           5.91
# 2         18995         KC           78.1          -1.38           5.99
# 3         18996         SL           79.5          -1.73           5.58
# 4         18997         KC           77.8          -1.28           5.98
# ...         ...        ...            ...            ...            ...
# 1208     264742         FF           96.1          -3.28           5.13
# 1209     264743         CU           79.7          -3.36           5.48
# 1210     264744         FF           96.7          -3.21           5.33
# 1211     264745         FF           96.1          -3.38           5.33
# 1212     264746         FF           95.3          -3.28           5.47
#
#         player_name  zone game_type stand p_throws  ... effective_speed  \
# ...
