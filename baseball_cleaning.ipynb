# %%
# Import dependencies
import pandas as pd

# %%
# Read in data
baseball_df = pd.read_csv('Data/Statcast/Statcast_2020.csv')

# %%
baseball_df.head(10)
# Out:
#    Unnamed: 0 pitch_type   game_date  release_speed  release_pos_x  \
# 0         691         FF  2020-09-29           98.8          -0.41
# 1         709         FF  2020-09-29           98.7          -0.33
# 2         720         SL  2020-09-29           89.6          -0.10
# 3         745         FF  2020-09-29          100.4          -0.38
# 4         760         FF  2020-09-29           97.6          -0.18
# 5         792         FF  2020-09-29           98.8          -0.31
# 6         820         FF  2020-09-29           99.1          -0.29
# 7         840         SL  2020-09-29           89.8          -0.20
# 8         870         SL  2020-09-29           86.7          -0.15
# 9         898         SL  2020-09-29           86.8          -0.19
#
#    release_pos_z      player_name  batter  pitcher     events  ... fld_score  \
# 0           6.46  Fairbanks, Pete  605412   664126  field_out  ...         3
# ...

# %%
# Save necessary columns to new df
pitch_df = baseball_df[['type', 'pitch_type', 'release_speed', 'effective_speed', 'release_spin_rate', 'release_pos_x', 'release_pos_z', 'zone', 'stand', 'p_throws', 'pitch_number']]

# %%
# Check new df
pitch_df.head(10)
# Out:
#   type pitch_type  release_speed  effective_speed  release_spin_rate  \
# 0    X         FF           98.8            100.2             2483.0
# 1    B         FF           98.7            100.0             2522.0
# 2    S         SL           89.6             90.8             2537.0
# 3    S         FF          100.4            101.7             2469.0
# 4    S         FF           97.6             98.9             2339.0
# 5    B         FF           98.8             99.9             2372.0
# 6    B         FF           99.1            100.4             2502.0
# 7    B         SL           89.8             91.0             2345.0
# 8    X         SL           86.7             87.9             2419.0
# 9    S         SL           86.8             88.1             2459.0
#
#    release_pos_x  release_pos_z  zone stand p_throws  pitch_number
# 0          -0.41           6.46  14.0     L        R             2
# 1          -0.33           6.62  12.0     L        R             1
# ...

# %%
# Drop columns with NAs 
pitch_df = pitch_df.dropna()

# %%
# Export new df as csv file
pitch_df.to_csv('Data/Saved/pitching_2020.csv')
