# %%
# Import dependcies
import pandas as pd
from sklearn import tree
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.ensemble import GradientBoostingClassifier

# Create global seed
yogi = 8

# %%
import sqlalchemy
import sqlite3 as sq
from sqlalchemy import create_engine, func
from sqlalchemy.orm import Session
from sqlalchemy.ext.automap import automap_base
import psycopg2

# %%
# Read in data 
file_path = 'team.csv'
pitchers_df = pd.read_csv(file_path)

pitchers_df.dropna(inplace = True)

pitchers_df.head(10)
# Out:
#    Unnamed: 0 pitch_type  release_speed  release_pos_x  release_pos_z  \
# 0       37703         FF           92.5          -1.44           5.56
# 1       30524         CU           75.5           2.47           5.62
# 2       30525         FF           90.1           2.40           5.74
# 3       30526         CU           75.9           2.52           5.49
# 4       30527         FT           90.2           2.60           5.59
# 5       30528         CH           85.0           2.55           5.49
# 6       30529         FT           90.8           2.52           5.53
# 7       30530         CH           84.9           2.53           5.45
# 8       30531         FF           89.6           2.39           5.62
# 9       30532         CU           76.9           2.49           5.53
#
#         player_name  zone game_type stand p_throws  ... release_spin_rate  \
# 0  Javier, Cristian  11.0         R     L        R  ...            2278.0
# 1     Erlin, Robbie  12.0         R     R        L  ...            2631.0
# 2     Erlin, Robbie  12.0         R     R        L  ...            2500.0
# 3     Erlin, Robbie   8.0         R     R        L  ...            2688.0
# 4     Erlin, Robbie  12.0         R     R        L  ...            2241.0
# 5     Erlin, Robbie   9.0         R     R        L  ...            1522.0
# 6     Erlin, Robbie  13.0         R     L        L  ...            2250.0
# 7     Erlin, Robbie   4.0         R     L        L  ...            1456.0
# 8     Erlin, Robbie  11.0         R     L        L  ...            2444.0
# 9     Erlin, Robbie  14.0         R     L        L  ...            2752.0
#
#    release_extension  release_pos_y  at_bat_number  pitch_number  \
# 0                6.0          54.49             19             4
# 1                5.9          54.64             39             5
# 2                6.0          54.54             39             4
# 3                6.0          54.53             39             3
# 4                6.2          54.28             39             2
# 5                6.1          54.41             39             1
# 6                6.6          53.90             38             7
# 7                6.2          54.31             38             6
# 8                6.0          54.47             38             5
# 9                6.1          54.35             38             4
#
#         pitch_name  spin_axis  delta_home_win_exp  delta_run_exp  team
# 0  4-Seam Fastball      202.0               0.000          0.000   ARI
# 1        Curveball      332.0               0.000          0.000   ARI
# 2  4-Seam Fastball      162.0               0.000          0.060   ARI
# 3        Curveball      336.0               0.000         -0.078   ARI
# 4  2-Seam Fastball      136.0               0.000          0.030   ARI
# 5         Changeup      131.0               0.000         -0.054   ARI
# 6  2-Seam Fastball      111.0               0.011         -0.462   ARI
# 7         Changeup      146.0               0.000          0.000   ARI
# 8  4-Seam Fastball      152.0               0.000          0.066   ARI
# 9        Curveball      339.0               0.000          0.000   ARI
#
# [10 rows x 36 columns]

# %%
# Create Engine
engine = create_engine('postgresql+psycopg2://postgres:**STAND IN PASSWORD**@localhost:5432/team_country_music')

# Create Base
Base = automap_base()

# Reflect
Base.prepare(engine, reflect=True)

# Save Base Class
Pitching = Base.classes.pitcher_data

# Create Session
session = Session(engine)

# Query Pitching Data
results = []
results = session.query(Pitching.ID,
                       Pitching.release_speed,
                       Pitching.zone,
                       Pitching.type,
                       Pitching.balls,
                       Pitching.strikes,
                       Pitching.inning,
                       Pitching.release_spin_rate,
                       Pitching.release_extension,
                       Pitching.pitch_number,
                       Pitching.pitch_type_CH,
                       Pitching.pitch_type_CS,
                       Pitching.pitch_type_CU,
                       Pitching.pitch_type_EP,
                       Pitching.pitch_type_FA,
                       Pitching.pitch_type_FC,
                       Pitching.pitch_type_FF,
                       Pitching.pitch_type_FO,
                       Pitching.pitch_type_FS,
                       Pitching.pitch_type_FT,
                       Pitching.pitch_type_KC,
                       Pitching.pitch_type_KN,
                        Pitching.pitch_type_SI,
                        Pitching.pitch_type_SL,
                        Pitching.pitch_type_nan,
                        Pitching.stand_R,
                        Pitching.p_throws_L,
                        Pitching.p_throws_R,
                        Pitching.player_name,
                       Pitching.pitch_type).all()

# Create DataFrame
pitchers_df = pd.DataFrame(results, columns=['ID',
                                         'release_speed',
                                         'zone',
                                         'type',
                                         'balls',
                                         'strikes',
                                         'inning',
                                         'release_spin_rate',
                                         'release_extension',
                                         'pitch_number',
                                         'pitch_type_CH',
                                          'pitch_type_CS',
                                          'pitch_type_CU',
                                          'pitch_type_EP',
                                          'pitch_type_FA',
                                          'pitch_type_FC',
                                          'pitch_type_FF',
                                          'pitch_type_FO',
                                          'pitch_type_FS',
                                          'pitch_type_FT',
                                          'pitch_type_KC',
                                          'pitch_type_KN',
                                          'pitch_type_SI',
                                          'pitch_type_SL',
                                          'pitch_type_nan',
                                          'stand_r',
                                          'p_throws_L',
                                          'p_throws_R',
                                          'player_name'
                                         ])
# Out:
# /Users/hayden/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    3140         try:
# -> 3141             return fn()
#    3142         except dialect.dbapi.Error as e:
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sqlalchemy/pool/base.py in connect(self)
#     300         """
# --> 301         return _ConnectionFairy._checkout(self)
#     302
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     754         if not fairy:
# --> 755             fairy = _ConnectionRecord.checkout(pool)
#     756
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     418     def checkout(cls, pool):
# --> 419         rec = pool._do_get()
#     420         try:
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     144                 with util.safe_reraise():
# --> 145                     self._dec_overflow()
#     146         else:
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      71                     exc_value,
# ---> 72                     with_traceback=exc_tb,
#      73                 )
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     210         try:
# --> 211             raise exception
#     212         finally:
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     141             try:
# --> 142                 return self._create_connection()
#     143             except:
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     246
# --> 247         return _ConnectionRecord(self)
#     248
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     361         if connect:
# --> 362             self.__connect(first_connect_check=True)
#     363         self.finalize_callback = deque()
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     604             with util.safe_reraise():
# --> 605                 pool.logger.debug("Error on connect(): %s", e)
#     606         else:
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      71                     exc_value,
# ---> 72                     with_traceback=exc_tb,
#      73                 )
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     210         try:
# --> 211             raise exception
#     212         finally:
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     598             self.starttime = time.time()
# --> 599             connection = pool._invoke_creator(self)
#     600             pool.logger.debug("Created new connection %r", connection)
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sqlalchemy/engine/create.py in connect(connection_record)
#     577                         return connection
# --> 578             return dialect.connect(*cargs, **cparams)
#     579
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     558         # inherits the docstring from interfaces.Dialect.connect
# --> 559         return self.dbapi.connect(*cargs, **cparams)
#     560
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/psycopg2/__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     129     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 130     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     131     if cursor_factory is not None:
#
# OperationalError: FATAL:  password authentication failed for user "postgres"
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-4-21b23a90cbc9> in <module>
#       6
#       7 # Reflect:
# ----> 8 Base.prepare(engine, reflect=True)
#       9
#      10 # Save reference to the table:
#
# <string> in prepare(cls, autoload_with, engine, reflect, schema, classname_for_table, collection_class, name_for_scalar_relationship, name_for_collection_relationship, generate_relationship, reflection_options)
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sqlalchemy/util/deprecations.py in warned(fn, *args, **kwargs)
#     296                         stacklevel=3,
#     297                     )
# --> 298             return fn(*args, **kwargs)
#     299
#     300         doc = fn.__doc__ is not None and fn.__doc__ or ""
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sqlalchemy/ext/automap.py in prepare(cls, autoload_with, engine, reflect, schema, classname_for_table, collection_class, name_for_scalar_relationship, name_for_collection_relationship, generate_relationship, reflection_options)
#     870             if reflection_options:
#     871                 opts.update(reflection_options)
# --> 872             cls.metadata.reflect(autoload_with, **opts)
#     873
#     874         with _CONFIGURE_MUTEX:
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sqlalchemy/sql/schema.py in reflect(self, bind, schema, views, only, extend_existing, autoload_replace, resolve_fks, **dialect_kwargs)
#    4654             bind = _bind_or_error(self)
#    4655
# -> 4656         with inspection.inspect(bind)._inspection_context() as insp:
#    4657             reflect_opts = {
#    4658                 "autoload_with": insp,
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sqlalchemy/inspection.py in inspect(subject, raiseerr)
#      62             if reg is True:
#      63                 return subject
# ---> 64             ret = reg(subject)
#      65             if ret is not None:
#      66                 break
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sqlalchemy/engine/reflection.py in _engine_insp(bind)
#     180     @inspection._inspects(Engine)
#     181     def _engine_insp(bind):
# --> 182         return Inspector._construct(Inspector._init_engine, bind)
#     183
#     184     @inspection._inspects(Connection)
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sqlalchemy/engine/reflection.py in _construct(cls, init, bind)
#     115
#     116         self = cls.__new__(cls)
# --> 117         init(self, bind)
#     118         return self
#     119
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sqlalchemy/engine/reflection.py in _init_engine(self, engine)
#     126     def _init_engine(self, engine):
#     127         self.bind = self.engine = engine
# --> 128         engine.connect().close()
#     129         self._op_context_requires_connect = True
#     130         self.dialect = self.engine.dialect
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sqlalchemy/engine/base.py in connect(self, close_with_result)
#    3093         """
#    3094
# -> 3095         return self._connection_cls(self, close_with_result=close_with_result)
#    3096
#    3097     @util.deprecated(
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sqlalchemy/engine/base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events)
#      89                 connection
#      90                 if connection is not None
# ---> 91                 else engine.raw_connection()
#      92             )
#      93
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sqlalchemy/engine/base.py in raw_connection(self, _connection)
#    3172
#    3173         """
# -> 3174         return self._wrap_pool_connect(self.pool.connect, _connection)
#    3175
#    3176
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    3143             if connection is None:
#    3144                 Connection._handle_dbapi_exception_noconnection(
# -> 3145                     e, dialect, self
#    3146                 )
#    3147             else:
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    2002         elif should_wrap:
#    2003             util.raise_(
# -> 2004                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2005             )
#    2006         else:
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    3139         dialect = self.dialect
#    3140         try:
# -> 3141             return fn()
#    3142         except dialect.dbapi.Error as e:
#    3143             if connection is None:
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sqlalchemy/pool/base.py in connect(self)
#     299
#     300         """
# --> 301         return _ConnectionFairy._checkout(self)
#     302
#     303     def _return_conn(self, record):
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     753     def _checkout(cls, pool, threadconns=None, fairy=None):
#     754         if not fairy:
# --> 755             fairy = _ConnectionRecord.checkout(pool)
#     756
#     757             fairy._pool = pool
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     417     @classmethod
#     418     def checkout(cls, pool):
# --> 419         rec = pool._do_get()
#     420         try:
#     421             dbapi_connection = rec.get_connection()
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     143             except:
#     144                 with util.safe_reraise():
# --> 145                     self._dec_overflow()
#     146         else:
#     147             return self._do_get()
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      70                 compat.raise_(
#      71                     exc_value,
# ---> 72                     with_traceback=exc_tb,
#      73                 )
#      74         else:
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     140         if self._inc_overflow():
#     141             try:
# --> 142                 return self._create_connection()
#     143             except:
#     144                 with util.safe_reraise():
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     245         """Called by subclasses to create a new ConnectionRecord."""
#     246
# --> 247         return _ConnectionRecord(self)
#     248
#     249     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     360         self.__pool = pool
#     361         if connect:
# --> 362             self.__connect(first_connect_check=True)
#     363         self.finalize_callback = deque()
#     364
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     603         except Exception as e:
#     604             with util.safe_reraise():
# --> 605                 pool.logger.debug("Error on connect(): %s", e)
#     606         else:
#     607             if first_connect_check:
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      70                 compat.raise_(
#      71                     exc_value,
# ---> 72                     with_traceback=exc_tb,
#      73                 )
#      74         else:
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     597         try:
#     598             self.starttime = time.time()
# --> 599             connection = pool._invoke_creator(self)
#     600             pool.logger.debug("Created new connection %r", connection)
#     601             self.connection = connection
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sqlalchemy/engine/create.py in connect(connection_record)
#     576                     if connection is not None:
#     577                         return connection
# --> 578             return dialect.connect(*cargs, **cparams)
#     579
#     580         creator = pop_kwarg("creator", connect)
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     557     def connect(self, *cargs, **cparams):
#     558         # inherits the docstring from interfaces.Dialect.connect
# --> 559         return self.dbapi.connect(*cargs, **cparams)
#     560
#     561     def create_connect_args(self, url):
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/psycopg2/__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     128
#     129     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 130     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     131     if cursor_factory is not None:
#     132         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) FATAL:  password authentication failed for user "postgres"
#
# (Background on this error at: http://sqlalche.me/e/14/e3q8)

# %%
# Define features set
X = pitchers_df
X.drop(columns = ['player_name', 'zone', 'balls', 'strikes'], axis = 1, inplace = True)
X.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9fe49e2ef767> in <module>
#       1 # Define features set
# ----> 2 X = pitchers_df
#       3 X.drop(columns = ['player_name', 'zone', 'balls', 'strikes'], axis = 1, inplace = True)
#       4 X.head()
#
# NameError: name 'pitchers_df' is not defined

# %%
# Define target vector
y = pitchers_df['zone'].values
y[:5]
# Out:
# array([11., 12., 12.,  8., 12.])

# %%
# Split the data into training and testing sets - stratify by pitcher
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = yogi)

# %%
# Create a StandardScaler instance
scaler = StandardScaler()

# Fit Standard Scaler 
X_scaler = scaler.fit(X_train)

# Scaling data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Create a classifier object
learning_rates = [0.05, 0.1, 0.25, 0.5, 0.75, 1]
best_rate = 0
best_acc = 0

for learning_rate in learning_rates:
    classifier = GradientBoostingClassifier(
        n_estimators = 20,
        learning_rate = learning_rate,
        max_features = 7,
        max_depth = 4,
        random_state = yogi)
    
    # Fit the model
    classifier.fit(X_train_scaled, y_train)
    print(f'Learning Rate: {learning_rate}')

    # Score the model
    print('Accuracy Score (training): {0:.3f}'.format(
        classifier.score(
            X_train_scaled,
            y_train
        )
    ))
    print('Accuracy Score (validation): {0:.3f}'.format(
        classifier.score(
            X_test_scaled,
            y_test
        )
    ))
    print()

    if classifier.score(X_test_scaled, y_test) > best_acc:
        best_acc = classifier.score(X_test_scaled, y_test)
        best_rate = learning_rate
# Out:
# Learning Rate: 0.05
# Accuracy Score (training): 0.528
# Accuracy Score (validation): 0.528
#
# Learning Rate: 0.1
# Accuracy Score (training): 0.804
# Accuracy Score (validation): 0.802
#
# Learning Rate: 0.25
# Accuracy Score (training): 0.871
# Accuracy Score (validation): 0.868
#
# Learning Rate: 0.5
# Accuracy Score (training): 0.906
# Accuracy Score (validation): 0.905
#
# Learning Rate: 0.75
# Accuracy Score (training): 0.915
# Accuracy Score (validation): 0.912
#
# Learning Rate: 1
# Accuracy Score (training): 0.918
# Accuracy Score (validation): 0.914

# %%
# Choose a learning rate and create classifiers
classifier = GradientBoostingClassifier(
    n_estimators = 20,
    learning_rate = best_rate,
    max_features = 7,
    max_depth = 3,
    random_state = yogi
)

# Fit the model
classifier.fit(X_train_scaled, y_train)

# Make predictions
predictions = classifier.predict(X_test_scaled)
pd.DataFrame({'Prediction': predictions, 'Actual': y_test}).head(20)
# Out:
#     Prediction  Actual
# 0          9.0     9.0
# 1         11.0    11.0
# 2          4.0     4.0
# 3          1.0     1.0
# 4         11.0    11.0
# 5         14.0    14.0
# 6          2.0     2.0
# 7          5.0     5.0
# 8         12.0    12.0
# 9          4.0     4.0
# 10         4.0     4.0
# 11        12.0    12.0
# 12        11.0    11.0
# 13        14.0    14.0
# 14         4.0     4.0
# 15        12.0    12.0
# 16         1.0     1.0
# 17         5.0     5.0
# 18         2.0     2.0
# 19         4.0     4.0

# %%
# Calculate accuracy score
acc_score = accuracy_score(y_test, predictions)
print(f'Accuracy Score: {acc_score}')
# Out:
# Accuracy Score: 0.905949986331719

# %%
# Generate classification report
print('Classification Report')
print(classification_report(y_test, predictions))
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#          1.0       0.84      0.83      0.83      9781
#          2.0       0.84      0.86      0.85     11266
#          3.0       0.86      0.85      0.86      8613
#          4.0       0.90      0.89      0.89     14283
#          5.0       0.91      0.91      0.91     17492
#          6.0       0.87      0.90      0.89     14326
#          7.0       0.89      0.93      0.91     12133
#          8.0       0.89      0.91      0.90     15438
#          9.0       0.89      0.86      0.88     14007
#         11.0       0.93      0.91      0.92     27194
#         12.0       0.88      0.88      0.88     19988
#         13.0       0.94      0.94      0.94     32734
#         14.0       0.94      0.94      0.94     47838
#
#     accuracy                           0.91    245093
#    macro avg       0.89      0.89      0.89    245093
# weighted avg       0.91      0.91      0.91    245093
